# %%
import sys
import os

# Add the project root directory to sys.path
sys.path.append(os.path.abspath(os.path.join('..')))

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from scipy.spatial.distance import cdist
from IPython.display import display
from scripts.experience_analytics import TelecomAnalyzer

# %%
data = pd.read_csv("../data/cleaned_data.csv")

# %%
analysis = TelecomAnalyzer(data)

# %%
analysis.run_analysis()
# Out:
# Top 10 customers by average TCP retransmission:
#                avg_tcp_retrans  avg_rtt  avg_throughput  \
# MSISDN/Number
# 3.366519e+10       353206167.0     57.0          5085.0
# 3.366815e+10       351440959.0     62.0         61441.0
# 3.365849e+10       348062089.0    202.0         41210.0
# 3.366714e+10       345341458.0     44.0          5790.0
# 3.365011e+10       344820925.0    107.0         59510.0
# 3.363184e+10       339178976.0     22.0          4358.0
# 3.366212e+10       335139152.0    379.0         44205.0
# 3.366031e+10       333378769.0     79.0         85005.0
# 3.376363e+10       332730218.0    106.0         29856.0
# 3.376067e+10       331641112.0     97.0         55757.0
#
#                                Handset Type
# MSISDN/Number
# 3.366519e+10     Xiaomi Communica. Redmi 4X
# 3.366815e+10               Huawei B528S-23A
# 3.365849e+10                   Huawei E5573
# 3.366714e+10        Apple iPhone 5S (A1457)
# 3.365011e+10               Huawei B528S-23A
# 3.363184e+10   Samsung Galaxy A3 (Sm-A310X)
# 3.366212e+10                   Huawei E5573
# 3.366031e+10                   Huawei E5180
# 3.376363e+10               Huawei B528S-23A
# 3.376067e+10               Huawei B528S-23A
# Top 10 customers by average RTT:
#                avg_tcp_retrans  avg_rtt  avg_throughput  \
# MSISDN/Number
# 3.366154e+10          150245.0   1702.0           609.0
# 3.367810e+10        29709711.0   1699.0           511.0
# 3.361283e+10         6063752.0   1698.0          7504.0
# 3.366768e+10           13190.0   1698.0           201.0
# 3.364967e+10           17290.0   1690.0            62.0
# 3.366921e+10           15032.0   1688.0           226.0
# 3.361631e+10         4916050.0   1687.0          3600.0
# 3.361153e+10        17748335.0   1685.0         11841.0
# 3.365892e+10            3978.0   1685.0            48.0
# 3.360932e+10          576028.0   1683.0          5526.0
#
#                                       Handset Type
# MSISDN/Number
# 3.366154e+10           Sony Mobile Comm. Xperia L1
# 3.367810e+10                             undefined
# 3.361283e+10          Samsung Galaxy S5 (Sm-G900X)
# 3.366768e+10                Apple iPhone 4 (A1332)
# 3.364967e+10                Apple iPhone 8 (A1905)
# 3.366921e+10                Apple iPhone 8 (A1905)
# 3.361631e+10                Apple iPhone 8 (A1905)
# 3.361153e+10                Apple iPhone 7 (A1778)
# 3.365892e+10           Samsung Galaxy J5 (Sm-J530)
# 3.360932e+10   Asustek Asus Zenfone Zoom S Ze553Kl
# Top 10 customers by average throughput:
#                avg_tcp_retrans  avg_rtt  avg_throughput  \
# MSISDN/Number
# 3.363780e+10         1597157.0     38.0         85244.0
# 3.366245e+10         6455199.0    195.0         85173.0
# 3.365923e+10         2915782.0     57.0         85145.0
# 3.366140e+10          521304.0     61.0         85136.0
# 3.366498e+10           22640.0     41.0         85114.0
# 3.365090e+10         8548866.0     48.0         85111.0
# 3.366532e+10        98182841.0     73.0         85084.0
# 3.366503e+10          513088.0     53.0         85030.0
# 3.366031e+10       333378769.0     79.0         85005.0
# 3.364354e+10         1380807.0     47.0         84991.0
#
#                                Handset Type
# MSISDN/Number
# 3.363780e+10                 Huawei Cor-L29
# 3.366245e+10        Apple iPad Mini (A1490)
# 3.365923e+10               Huawei B528S-23A
# 3.366140e+10   Samsung Galaxy S7 (Sm-G930X)
# 3.366498e+10        Apple iPhone Se (A1723)
# 3.365090e+10                      undefined
# 3.366532e+10               Huawei B528S-23A
# 3.366503e+10               Huawei B528S-23A
# 3.366031e+10                   Huawei E5180
# 3.364354e+10        Apple iPhone Se (A1723)
# Top 10 Handset Types:
# Handset Type
# Huawei B528S-23A                10615
# Apple iPhone 6S (A1688)          6759
# undefined                        6670
# Apple iPhone 6 (A1586)           6260
# Apple iPhone 7 (A1778)           4699
# Apple iPhone Se (A1723)          3754
# Apple iPhone 8 (A1905)           3543
# Samsung Galaxy S8 (Sm-G950F)     3245
# Apple iPhone Xr (A2105)          3072
# Samsung Galaxy J5 (Sm-J530)      2748
# Name: count, dtype: int64
# Explained variance ratio: [0.8423329  0.12462554]
#
# Cluster statistics:
#         avg_tcp_retrans                            avg_rtt          \
#                     min          max          mean     min     max
# cluster
# 0                   4.0  281750313.0  5.476296e+06   409.5  1702.0
# 1                   2.0  353206167.0  1.374445e+06     0.0   442.0
# 2                  35.0  351440959.0  8.862674e+06    15.0   995.0
#
#                     avg_throughput
#                mean            min      max          mean
# cluster
# 0        811.426145            0.0  56646.0   6288.362732
# 1         57.070506            0.0  21259.0   2932.310076
# 2         75.507564        17603.0  85244.0  39418.200182
# c:\Users\Ashis\Desktop\KAIM Program 2\cloned_week2\KAIM_week2\scripts\experience_analytics.py:97: UserWarning: When passing multiple axes, sharex and sharey are ignored. These settings must be specified when creating axes.
#   self.customer_metrics.boxplot(column=numerical_columns, by='cluster', ax=axes)
# Average Throughput by Handset Type:
# Handset Type
# Zyxel Communicat. Sbg3600                 82818.0
# Huawei Pele                               76474.0
# Shenzhen Leagoo. Leagoo S8                74086.0
# Spa Condor Elect. Plume L2                73997.0
# Doke Communicati. Blackview Bv6800 Pro    72595.0
# A-Link Telecom I. Cubot Power             69126.0
# Huawei Aum-Al00                           65466.0
# Oppo Cph1723                              65257.0
# Huawei Y6 Prime 2018                      64615.0
# Huawei Hwi-Al00                           63237.0
# Name: avg_throughput, dtype: float64
