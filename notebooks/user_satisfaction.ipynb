# %%
import sys
import os

# Add the project root directory to sys.path
sys.path.append(os.path.abspath(os.path.join('..')))

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
from scipy.spatial.distance import cdist
from IPython.display import display
from scripts.user_satisfaction import UserSatisfactionAnalysis

# %%
data = pd.read_csv("../data/cleaned_data.csv")

# %%
analysis = UserSatisfactionAnalysis(data)

# %%
analysis.analysis_run()
# Out:
# Top 10 Satisfied Customers:
#            Bearer Id  satisfaction_score
# 140755  7.277826e+18           48.975024
# 138156  7.277826e+18           47.841834
# 37016   7.277826e+18           47.627701
# 40338   7.277826e+18           47.566829
# 139212  1.304243e+19           47.252908
# 142638  1.304243e+19           47.166001
# 134799  1.304243e+19           46.979766
# 59340   7.277826e+18           46.321001
# 83063   1.304243e+19           45.234714
# 783     1.304243e+19           45.057443
#
# Regression Model Results:
# Mean Squared Error: 0.3433145731369784
# R-squared Score: 0.8412807873376476
#
# Cluster Averages:
#          engagement_score  experience_score  satisfaction_score
# cluster
# 0                1.063201          2.823735            1.943468
# 1                8.055245          6.945322            7.500284
#
# MySQL Query Result:
# MySQL Query Result:
#       Bearer Id  engagement_score  experience_score  satisfaction_score
# 0  1.311448e+19          0.278129          3.139905            1.709017
# 1  1.311448e+19          0.212446          3.119080            1.665763
# 2  1.311448e+19          0.268593          3.144267            1.706430
# 3  1.311448e+19          0.261434          3.135229            1.698332
# 4  1.311448e+19          0.268593          3.144267            1.706430
# 5  1.311448e+19          0.258976          3.132114            1.695545
# 6  1.311448e+19          0.380920          3.100710            1.740815
# 7  1.304243e+19          0.647671          2.716897            1.682284
# 8  1.311448e+19          0.260579          3.134064            1.697321
# 9  1.304243e+19          0.966821          2.439258            1.703040
# 2024/09/10 01:38:18 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2024/09/10 01:38:18 INFO mlflow.tracking._tracking_service.client: 🏃 View run puzzled-fly-759 at: http://localhost:5000/#/experiments/1/runs/a26275ee96114407b883033736fe5293.
# 2024/09/10 01:38:18 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://localhost:5000/#/experiments/1.
# MLflow run ID: a26275ee96114407b883033736fe5293
# MLflow experiment ID: 1
# Analysis complete. Data exported to MySQL, model tracked with MLflow, and satisfaction distribution plotted.
